# %%
import pandas as pd
import numpy as np
import random

# %%
subset = ['Compound', 'CAS ID', 'MWT',]
comps = pd.read_csv('/Users/Emily/Desktop/CB4856_screen/compounds_calcs.csv', usecols=subset)
comps = comps.replace('NaN', pd.NA).dropna(axis=0)
# Out:
# C:\ProgramData\Anaconda3\envs\neuroplant\lib\site-packages\IPython\core\interactiveshell.py:3156: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ref_data_dict = {'Compound': ['DMSO', 'H2O', 'Diacetyl', 'Isoamyl alcohol', '2-nonanone', '1-octanol'],
            'CAS ID' : ['67-68-5', '7732-18-5', '431-03-8', '123-51-3', '821-55-6', '111-87-5']}
ref_data = pd.DataFrame(ref_data_dict, columns=['Compound', 'CAS ID'])
final = pd.concat([comps, ref_data]).reset_index(drop=True)
final
# Out:
#                      Compound       CAS ID      MWT
# 0             (-)-Huperzine A  102518-79-6   242.32
# 1   2,5-Dihydroxybenzoic acid     490-79-9   154.12
# 2                Acetophenone      98-86-2   120.15
# 3                     Camphor      76-22-2   152.23
# 4                    Carnosol    5957-80-2   330.42
# 5            Cinnamyl Alcohol     104-54-1   134.18
# 6                    Coumaran     496-16-2   120.15
# 7                 Daucosterol     474-58-8   576.85
# 8                Ellagic acid     476-66-4   302.19
# 9             Ethyl palmitate     628-97-7   284.48
# 10               Isoquinoline     119-65-3   129.16
# 11                   Lapachol      84-79-7   242.27
# 12                  Leonurine   24697-74-3   311.33
# 13                    Limonin    1180-71-8   470.51
# 14             Oleanolic Acid     508-02-1   456.70
# 15             p-Tolualdehyde     104-87-0   120.15
# 16               Paeoniflorin   23180-57-6   480.46
# 17                     Phytol     150-86-7   296.53
# 18                   Sabinene    3387-41-5   136.23
# 19   Sinomenine hydrochloride    6080-33-7   365.85
# 20                 Solasodine     126-17-0   413.64
# 21               Ursolic acid      77-52-1   456.70
# 22                Guaiazulene     489-84-9   198.30
# 23    Salvinorin A Propionate  689295-71-4   446.50
# 24             α-Phellandrene      99-83-2   136.20
# 25                   Spinosad  168316-95-8  1478.00
# 26               Piperitenone     491-09-8   150.20
# 27   Ethyl p-methoxycinnamate   24393-56-4   206.20
# 28                 L-Mimosine     500-44-7   198.18
# 29      2,3-Dihydrobenzofuran     496-16-2   120.15
# 30            Phenylacetylene     536-74-3   102.13
# 31                  Thiophene     110-02-1    84.14
# 32                    Anisole     100-66-3   108.14
# 33         2-Methyl-1-butanol     137-32-6    88.15
# 34                   Furfural      98-01-1    96.09
# 35           Methyl palmitate     112-39-0   270.46
# 36          Piperonyl Alcohol     120-57-0   150.13
# 37                       DMSO      67-68-5      NaN
# 38                        H2O    7732-18-5      NaN
# 39                   Diacetyl     431-03-8      NaN
# 40            Isoamyl alcohol     123-51-3      NaN
# 41                 2-nonanone     821-55-6      NaN
# 42                  1-octanol     111-87-5      NaN

# %%
compounds = final['Compound']
random.Random(123).shuffle(compounds)
compounds
# Out:
# C:\ProgramData\Anaconda3\envs\neuroplant\lib\random.py:278: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]
# 0                       Anisole
# 1                          DMSO
# 2                p-Tolualdehyde
# 3       Salvinorin A Propionate
# 4         2,3-Dihydrobenzofuran
# 5                     Thiophene
# 6                  Ellagic acid
# 7                Oleanolic Acid
# 8               Ethyl palmitate
# 9      Ethyl p-methoxycinnamate
# 10                     Sabinene
# 11                 Paeoniflorin
# 12    2,5-Dihydroxybenzoic acid
# 13             Methyl palmitate
# 14                     Lapachol
# 15                     Diacetyl
# 16                     Spinosad
# 17                   Solasodine
# 18                    Leonurine
# 19     Sinomenine hydrochloride
# 20            Piperonyl Alcohol
# 21                      Limonin
# 22              (-)-Huperzine A
# 23              Phenylacetylene
# 24                  Daucosterol
# 25                  Guaiazulene
# 26                   L-Mimosine
# 27                          H2O
# 28                 Isoquinoline
# 29                     Carnosol
# 30              Isoamyl alcohol
# 31                    1-octanol
# 32           2-Methyl-1-butanol
# 33                 Ursolic acid
# 34                     Furfural
# 35               α-Phellandrene
# 36                 Acetophenone
# 37                     Coumaran
# 38                   2-nonanone
# 39                 Piperitenone
# 40             Cinnamyl Alcohol
# 41                       Phytol
# 42                      Camphor
# Name: Compound, dtype: object

# %%
lets = [] #Creating an empty list to hold row values
lets = np.array(['B', 'C', 'D', 'E', 'F', 'G']) # Adding row values


lets = list(np.repeat(lets, [8], axis=0))# Extending the list of row values for all 96 conditions
lets = lets*4
# Out:
# ['B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G']

# %%
nums = [] #Creating an empty list to hold column values
nums = ['2', '3', '4', '5', '8', '9', '10', '11'] # Adding appropriate PCR plate column values
nums = nums*24 # Extending the list of numbers to accomodate 96 conditions

shuffled['Num'] = nums[0:len(shuffled)] # Adding column values to the randomized/shuffled df of compounds
shuffled['Let'] = lets[0:len(shuffled)] # Adding row values to the randomized/shuffled df of compounds
shuffled["Compound Well"] =  shuffled["Let"] + shuffled["Num"] #Combining the row/column value into 1 field
#compound_locs = compound_locs.drop(['Num', 'Let'], axis=1)
shuffled = shuffled.drop(columns=['Num', 'Let'])
shuffled
# Out:
#                      Compound Compound Well
# 0                     Anisole            B2
# 1                        DMSO            B3
# 2              p-Tolualdehyde            B4
# 3     Salvinorin A Propionate            B5
# 4       2,3-Dihydrobenzofuran            B8
# 5                   Thiophene            B9
# 6                Ellagic acid           B10
# 7              Oleanolic Acid           B11
# 8             Ethyl palmitate            C2
# 9    Ethyl p-methoxycinnamate            C3
# 10                   Sabinene            C4
# 11               Paeoniflorin            C5
# 12  2,5-Dihydroxybenzoic acid            C8
# 13           Methyl palmitate            C9
# 14                   Lapachol           C10
# 15                   Diacetyl           C11
# 16                   Spinosad            D2
# 17                 Solasodine            D3
# 18                  Leonurine            D4
# 19   Sinomenine hydrochloride            D5
# 20          Piperonyl Alcohol            D8
# 21                    Limonin            D9
# 22            (-)-Huperzine A           D10
# 23            Phenylacetylene           D11
# 24                Daucosterol            E2
# 25                Guaiazulene            E3
# 26                 L-Mimosine            E4
# 27                        H2O            E5
# 28               Isoquinoline            E8
# 29                   Carnosol            E9
# 30            Isoamyl alcohol           E10
# 31                  1-octanol           E11
# 32         2-Methyl-1-butanol            F2
# 33               Ursolic acid            F3
# 34                   Furfural            F4
# 35             α-Phellandrene            F5
# 36               Acetophenone            F8
# 37                   Coumaran            F9
# 38                 2-nonanone           F10
# 39               Piperitenone           F11
# 40           Cinnamyl Alcohol            G2
# 41                     Phytol            G3
# 42                    Camphor            G4

# %%
shuffled.to_csv('/Users/Emily/Desktop/CB4856_screen/cb4856_platelocs.csv')
